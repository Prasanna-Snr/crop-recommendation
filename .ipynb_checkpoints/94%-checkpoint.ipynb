# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
import warnings
# %matplotlib inline

# %% [markdown]
# # Loda Dataset

# %%
df = pd.read_csv("C:/Users/prasa/Desktop/crop recommendation/dataset/crops.csv")

# %% [markdown]
# # EDA

# %%
print("Display the first 10 rows")
df.head(10)
# Out:
# Display the first 10 rows
#            N          P          K    rainfall  temperature   humidity  \
# 0  57.450712  31.858063  48.482862   81.165682    22.168855  71.473092
# 1  47.926035  36.334006  47.833236  136.700861    31.076215  69.038377
# 2  59.715328  32.831427  35.634802  164.778296    23.810879  84.276861
# 3  72.845448  41.325017  50.795842  208.980135    25.543416  92.992467
# 4  46.487699  54.366142  30.099173  261.449740    29.304344  80.302704
# 5  46.487946  30.747494  38.458157  241.648157    24.646220  85.173156
# 6  73.688192  52.009846  25.009122  129.240512    14.092913  66.738937
# 7  61.511521  30.619935  60.586265  177.697264    31.243525  71.881072
# 8  42.957884  29.828473  42.684505  204.582535    32.529573  92.285981
# 9  58.138401  49.823135  66.668840  184.267573    14.013303  77.900672
#
#          ph        label
# 0  6.563070    Sugarcane
# 1  6.950318        Mango
# 2  6.772882  Cauliflower
# 3  5.477669       Tomato
# 4  6.351024        Maize
# 5  7.022224      Cabbage
# 6  6.834432       Millet
# 7  5.874504      Soybean
# 8  6.832723        Maize
# 9  7.231911       Lentil

# %% [markdown]
# ### Data types of feature

# %%
df.dtypes
# Out:
# N              float64
# P              float64
# K              float64
# rainfall       float64
# temperature    float64
# humidity       float64
# ph             float64
# label           object
# dtype: object

# %% [markdown]
# ### checking missing and duplicate values

# %%
# Checking missing values
missing_v = df.isnull().sum()

# Percentage of missing values per column
missing_percent_col = (missing_v / len(df)) * 100

# Total missing values in dataset
total_missing = missing_v.sum()
# Percentage of missing values in entire dataset
total_missing_percent = (total_missing / (df.shape[0] * df.shape[1])) * 100

# Printing results
print("Missing values per column:\n", missing_v)
print("\nPercentage of missing values per column:\n", missing_percent_col.round(2))
print("\nTotal missing values:", total_missing)
print(f"Percentage of missing values in the dataset: {total_missing_percent:.2f}%")
print("\nDuplicate rows ",df.duplicated().sum())
# Out:
# Missing values per column:
#  N              60
# P              50
# K              55
# rainfall       45
# temperature     0
# humidity       55
# ph             38
# label           0
# dtype: int64
#
# Percentage of missing values per column:
#  N              0.60
# P              0.50
# K              0.55
# rainfall       0.45
# temperature    0.00
# humidity       0.55
# ph             0.38
# label          0.00
# dtype: float64
#
# Total missing values: 303
# Percentage of missing values in the dataset: 0.38%
#
# Duplicate rows  0

# %% [markdown]
# ### Handling duplicates and missing values

# %%
# remove missing values
df.dropna(inplace=True)

# remove first row if duplicate row exists 
df.drop_duplicates(keep='first',inplace=True)

print("After data clening")
print("Missing values per columns\n",df.isnull().sum())
print("\nDuplicate row ",df.duplicated().sum())
# Out:
# After data clening
# Missing values per columns
#  N              0
# P              0
# K              0
# rainfall       0
# temperature    0
# humidity       0
# ph             0
# label          0
# dtype: int64
#
# Duplicate row  0

# %%
df.dtypes
# Out:
# N              float64
# P              float64
# K              float64
# rainfall       float64
# temperature    float64
# humidity       float64
# ph             float64
# label           object
# dtype: object

# %% [markdown]
# ### Statistical Summary of the Dataset

# %%
df.describe()
# Out:
#                  N            P            K     rainfall  temperature  \
# count  9697.000000  9697.000000  9697.000000  9697.000000  9697.000000
# mean     50.252197    40.379385    45.110951   200.909754    25.048405
# std      16.267782    12.720458    11.251613    65.640830     6.004673
# min      -8.836004    -6.276504     8.449135   -11.969091    -0.772346
# 25%      39.925649    32.062145    38.007368   158.348776    21.018290
# 50%      50.011333    40.218772    44.972644   199.653817    25.060903
# 75%      60.168888    48.405965    51.705600   241.152514    29.130433
# max     263.212679   174.638819   245.794795  1090.156514    46.219190
#
#           humidity           ph
# count  9697.000000  9697.000000
# mean     70.022193     6.509022
# std      15.162079     0.794766
# min       7.633992     3.519087
# 25%      59.823318     5.962910
# 50%      70.152169     6.516511
# 75%      80.339357     7.045429
# max     126.180688     9.328838

# %% [markdown]
# # Feature engineering
# ### Checking outliers

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,4,1)
plt.boxplot(df['N'])
plt.title("N")

plt.subplot(2,4,2)
plt.boxplot(df['P'])
plt.title("P")

plt.subplot(2,4,3)
plt.boxplot(df['K'])
plt.title("K")

plt.subplot(2,4,4)
plt.boxplot(df['rainfall'])
plt.title("rainfall")


plt.subplot(2,4,5)
plt.boxplot(df['temperature'])
plt.title("temperature")

plt.subplot(2,4,6)
plt.boxplot(df['humidity'])
plt.title("humidity")

plt.subplot(2,4,7)
plt.boxplot(df['ph'])
plt.title("ph")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Remove outlier

# %%
cols = ['N','P','K','rainfall','temperature','humidity','ph']

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    IQR = q3 - q1

    lower = q1 - 1.5 * IQR
    upper = q3 + 1.5 * IQR

    # Remove outliers
    df = df[(df[col] >= lower) & (df[col] <= upper)]
df.shape
# Out:
# (9170, 8)

# %% [markdown]
# ### After remove outlier

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,4,1)
plt.boxplot(df['N'])
plt.title("N")

plt.subplot(2,4,2)
plt.boxplot(df['P'])
plt.title("P")

plt.subplot(2,4,3)
plt.boxplot(df['K'])
plt.title("K")

plt.subplot(2,4,4)
plt.boxplot(df['rainfall'])
plt.title("rainfall")


plt.subplot(2,4,5)
plt.boxplot(df['temperature'])
plt.title("temperature")

plt.subplot(2,4,6)
plt.boxplot(df['humidity'])
plt.title("humidity")

plt.subplot(2,4,7)
plt.boxplot(df['ph'])
plt.title("ph")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature transformation

# %%
# uniue crops 
df['label'].unique()
# Out:
# array(['Sugarcane', 'Mango', 'Cauliflower', 'Tomato', 'Maize', 'Cabbage',
#        'Millet', 'Soybean', 'Lentil', 'Apple', 'Wheat', 'Chili',
#        'Mustard', 'Rice', 'Onion', 'Banana', 'Potato', 'Barley', 'Garlic',
#        'Pea'], dtype=object)

# %%
crops_dict = {
    "Sugarcane": 1,
    "Mango": 2,
    "Cauliflower": 3,
    "Tomato": 4,
    "Maize": 5,
    "Cabbage": 6,
    "Millet": 7,
    "Soybean": 8,
    "Lentil": 9,
    "Apple": 10,
    "Wheat": 11,
    "Chili": 12,
    "Mustard": 13,
    "Rice": 14,
    "Onion": 15,
    "Banana": 16,
    "Potato": 17,
    "Barley": 18,
    "Garlic": 19,
    "Pea": 20
}

df['label_num']=df['label'].map(crops_dict)
df.head()
# Out:
#            N          P          K    rainfall  temperature   humidity  \
# 0  57.450712  31.858063  48.482862   81.165682    22.168855  71.473092
# 1  47.926035  36.334006  47.833236  136.700861    31.076215  69.038377
# 2  59.715328  32.831427  35.634802  164.778296    23.810879  84.276861
# 3  72.845448  41.325017  50.795842  208.980135    25.543416  92.992467
# 4  46.487699  54.366142  30.099173  261.449740    29.304344  80.302704
#
#          ph        label  label_num
# 0  6.563070    Sugarcane          1
# 1  6.950318        Mango          2
# 2  6.772882  Cauliflower          3
# 3  5.477669       Tomato          4
# 4  6.351024        Maize          5

# %% [markdown]
# # Select independent and target variable

# %%
# independent feature 
features =['N','P','K','rainfall','temperature','humidity','ph']
X = df[features]

# target variable
y=df['label_num']

# %% [markdown]
# # Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
std_scaler= StandardScaler()
X_train=std_scaler.fit_transform(X_train)
X_test=std_scaler.transform(X_test)

# %% [markdown]
# # Creating and training model

# %%
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Hyperparameter Tuning using GridSearchCV

# %%
# Define hyperparameters to tune
param_grid = {
    'n_estimators': [100,150,200],
    'max_depth': [10,20,None],
    'min_samples_split': [2, 5, 10]
}

# %% [markdown]
# ### Train model

# %%
model = GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,scoring='accuracy')
model.fit(X_train,y_train)

# %%
print("The best parameter is ",model.best_params_)
print("\nThe best score is ",model.best_score_)
# Out:
# The best parameter is  {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 20}
#
# The best score is  0.053434439822942235
